# %% [markdown]
# # Transfer Learning on Tensorflow
#
# Simple to follow notebook, based on official Tensorflow docs.

# %%
# Import required libraries

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import os
import tensorflow as tf
# Out:
# 2022-08-29 07:43:25.023620: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
print(matplotlib.__version__)
print(tf.__version__)
print(np.__version__)
# Out:
# 3.5.2
# 2.9.0
# 1.23.2

# %% [markdown]
# Now we need our dataset. For this, we will use the cats and dogs dataset.
#
# tf.keras has a function to download files from the internet, and extract them if necessary.

# %%
url = 'https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip'

# This line downloads the file, and extracts the zip file.
# The download location will be shown later
download_zip_file = tf.keras.utils.get_file('cats_and_dogs_filtered.zip', origin=url, extract=True)

# %%
file_path = os.path.join(os.path.dirname(download_zip_file), 'cats_and_dogs_filtered')
print(file_path)
# Out:
# /home/venom/.keras/datasets/cats_and_dogs_filtered

# %%
os.listdir(file_path)
# Out:
# ['validation', 'train', 'vectorize.py']

# %%
# Now that we have the data, we have to create a dataset from it.
# From previous cell, we know the folder structure of the dataset.
img_size = (224, 224)
file_path_train = os.path.join(file_path, 'train')
train_dataset = tf.keras.utils.image_dataset_from_directory(file_path_train, image_size=img_size)
# Out:
# Found 2000 files belonging to 2 classes.
# 2022-08-29 07:43:29.124832: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-29 07:43:29.193210: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-29 07:43:29.193485: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-29 07:43:29.194260: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-08-29 07:43:29.195890: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-29 07:43:29.196158: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-29 07:43:29.196311: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-29 07:43:29.654884: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-29 07:43:29.655159: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-29 07:43:29.655288: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-29 07:43:29.655408: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4134 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
file_path_validation = os.path.join(file_path, 'validation')
validation_dataset = tf.keras.utils.image_dataset_from_directory(file_path_validation,image_size=img_size)
# Out:
# Found 1000 files belonging to 2 classes.

# %% [markdown]
# Comming to the pretrained nertwork part
#
# Here we are going to use mobile net as our pretrained network.
#
# Every netowrk, has some rules for the input layer. It includes image size and normalization.
#
# Kers does this for us, by having function for some pretrained networks

# %%
preprocess_input = tf.keras.applications.mobilenet_v2.preprocess_input

# %%
# According to mobileNetV2 documentation, the input shape is 224x224x3.
# We will use this shape for all the images.

img_size = img_size # (224, 224)
img_shape = img_size + (3,)

# %%
# Getting our base model

base_model = tf.keras.applications.MobileNetV2(input_shape=img_shape, 
                                               include_top=False, 
                                               weights='imagenet')

# %% [markdown]
# Transfer learning begins

# %%
# Freezing the entire model
base_model.trainable = False

# %%
# The output layer we want will be a binary classification layer.
# It will have only 1 mode

prediction_layer = tf.keras.layers.Dense(1)

# %%
# Putting all this together

input = tf.keras.Input(shape=img_shape)
x = preprocess_input(input)
x = base_model(x)
x = tf.keras.layers.GlobalAveragePooling2D()(x)
outputs = prediction_layer(x)
model = tf.keras.Model(inputs=input, outputs=outputs)

# %%
# Compile the model

base_learning_rate = 0.0001
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.math.truediv (TFOpLambda  (None, 224, 224, 3)      0
#  )
#
#  tf.math.subtract (TFOpLambd  (None, 224, 224, 3)      0
#  a)
#
#  mobilenetv2_1.00_224 (Funct  (None, 7, 7, 1280)       2257984
#  ional)
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 1)                 1281
#
# =================================================================
# Total params: 2,259,265
# Trainable params: 1,281
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
loss0, accuracy0 = model.evaluate(validation_dataset, batch_size=32, workers=4)
print("initial loss: {:.2f}".format(loss0))
print("initial accuracy: {:.2f}".format(accuracy0))
# Out:
# 2022-08-29 07:43:33.839448: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8401
# 32/32 [==============================] - 5s 49ms/step - loss: 0.6868 - accuracy: 0.5520
# initial loss: 0.69
# initial accuracy: 0.55

# %% [markdown]
# Now we train this!

# %%
initial_epochs = 10

# Training the model
history = model.fit(train_dataset, epochs=initial_epochs,
                    validation_data=validation_dataset,
                    batch_size=32,
                    workers=4)
# Out:
# Epoch 1/10
# 63/63 [==============================] - 6s 64ms/step - loss: 0.5494 - accuracy: 0.6530 - val_loss: 0.4311 - val_accuracy: 0.7710
# Epoch 2/10
# 63/63 [==============================] - 4s 59ms/step - loss: 0.3609 - accuracy: 0.8310 - val_loss: 0.2981 - val_accuracy: 0.8780
# Epoch 3/10
# 63/63 [==============================] - 4s 59ms/step - loss: 0.2607 - accuracy: 0.9135 - val_loss: 0.2250 - val_accuracy: 0.9250
# Epoch 4/10
# 63/63 [==============================] - 4s 59ms/step - loss: 0.2037 - accuracy: 0.9455 - val_loss: 0.1806 - val_accuracy: 0.9480
# Epoch 5/10
# 63/63 [==============================] - 4s 60ms/step - loss: 0.1674 - accuracy: 0.9590 - val_loss: 0.1513 - val_accuracy: 0.9600
# Epoch 6/10
# 63/63 [==============================] - 4s 66ms/step - loss: 0.1431 - accuracy: 0.9680 - val_loss: 0.1309 - val_accuracy: 0.9680
# Epoch 7/10
# 63/63 [==============================] - 4s 61ms/step - loss: 0.1258 - accuracy: 0.9720 - val_loss: 0.1160 - val_accuracy: 0.9730
# Epoch 8/10
# 63/63 [==============================] - 4s 67ms/step - loss: 0.1127 - accuracy: 0.9745 - val_loss: 0.1047 - val_accuracy: 0.9730
# Epoch 9/10
# 63/63 [==============================] - 4s 67ms/step - loss: 0.1025 - accuracy: 0.9765 - val_loss: 0.0956 - val_accuracy: 0.9770
# Epoch 10/10
# 63/63 [==============================] - 4s 67ms/step - loss: 0.0942 - accuracy: 0.9780 - val_loss: 0.0883 - val_accuracy: 0.9770

# %% [markdown]
# Plotting the model's performance over training time

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(12, 12))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()), 1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0, 1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# Now we have a model that works for our usecase.
#
# We can further improve this model by fine tuning the network.
#
# Here, we unfreeze parts of the netowrk and put them in the training loop --> Fine tuning the layers

# %%
# Let's take a look to see how many layers are in the base model
print("Number of layers in the base model: ", len(base_model.layers))
# Out:
# Number of layers in the base model:  154

# %%
base_model.trainable = True

# %%
# Fine-tune from this layer onwards
fine_tune_at = 100

# Freeze all the layers before the `fine_tune_at` layer
for layer in base_model.layers[:fine_tune_at]:
  layer.trainable = False

# %%
model.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              optimizer=tf.keras.optimizers.RMSprop(
              learning_rate=base_learning_rate/10),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.math.truediv (TFOpLambda  (None, 224, 224, 3)      0
#  )
#
#  tf.math.subtract (TFOpLambd  (None, 224, 224, 3)      0
#  a)
#
#  mobilenetv2_1.00_224 (Funct  (None, 7, 7, 1280)       2257984
#  ional)
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 1)                 1281
#
# =================================================================
# Total params: 2,259,265
# Trainable params: 1,862,721
# Non-trainable params: 396,544
# _________________________________________________________________

# %%
fine_tune_epochs = 10
total_epochs = initial_epochs + fine_tune_epochs

#Fine-tune the model

# Training the model
history_fine = model.fit(train_dataset,
                    epochs=total_epochs,
                    initial_epoch=history.epoch[-1] + 1, # The epoch number of the last training epoch
                    validation_data=validation_dataset,
                    batch_size=32,
                    workers=4)
# Out:
# Epoch 11/20
# 2022-08-29 07:44:23.019466: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 63/63 [==============================] - 10s 93ms/step - loss: 0.2743 - accuracy: 0.9055 - val_loss: 0.0655 - val_accuracy: 0.9840
# Epoch 12/20
# 63/63 [==============================] - 5s 81ms/step - loss: 0.1185 - accuracy: 0.9640 - val_loss: 0.0593 - val_accuracy: 0.9850
# Epoch 13/20
# 63/63 [==============================] - 5s 82ms/step - loss: 0.0710 - accuracy: 0.9770 - val_loss: 0.0461 - val_accuracy: 0.9880
# Epoch 14/20
# 63/63 [==============================] - 5s 82ms/step - loss: 0.0546 - accuracy: 0.9870 - val_loss: 0.0412 - val_accuracy: 0.9880
# Epoch 15/20
# 63/63 [==============================] - 5s 82ms/step - loss: 0.0405 - accuracy: 0.9885 - val_loss: 0.0312 - val_accuracy: 0.9900
# Epoch 16/20
# 63/63 [==============================] - 5s 82ms/step - loss: 0.0328 - accuracy: 0.9925 - val_loss: 0.0275 - val_accuracy: 0.9910
# Epoch 17/20
# 63/63 [==============================] - 5s 82ms/step - loss: 0.0273 - accuracy: 0.9950 - val_loss: 0.0286 - val_accuracy: 0.9910
# Epoch 18/20
# 63/63 [==============================] - 5s 82ms/step - loss: 0.0196 - accuracy: 0.9955 - val_loss: 0.0243 - val_accuracy: 0.9920
# Epoch 19/20
# 63/63 [==============================] - 5s 82ms/step - loss: 0.0165 - accuracy: 0.9965 - val_loss: 0.0231 - val_accuracy: 0.9930
# Epoch 20/20
# 63/63 [==============================] - 5s 82ms/step - loss: 0.0245 - accuracy: 0.9920 - val_loss: 0.0238 - val_accuracy: 0.9900

# %%
# Adding our new metrics to the existing history

acc += history_fine.history['accuracy']
val_acc += history_fine.history['val_accuracy']

loss += history_fine.history['loss']
val_loss += history_fine.history['val_loss']

# %%
plt.figure(figsize=(12, 12))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.ylim([0.8, 1])
plt.plot([initial_epochs-1, initial_epochs-1],
         plt.ylim(), label='Start Fine Tuning')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.ylim([0, 1.0])
plt.plot([initial_epochs-1, initial_epochs-1],
         plt.ylim(), label='Start Fine Tuning')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# Transfer learning and fine tuning done!
